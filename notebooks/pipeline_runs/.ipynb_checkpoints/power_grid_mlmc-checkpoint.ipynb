# %%
import sys
sys.path.append(r"C:\Users\Rakesh\Documents\summer-project")
sys.path.append(r"C:\Users\Rakesh\Documents\summer-project\src")

from functions_v2 import *
from two_level_mc import TwoLevelSetup
from graph_mlmc_model import GraphTwoLevelModel
from mlmc_runner import MLMCRunner
from sksparse.cholmod import cholesky as sparse_cholesky
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 8
#       6 from two_level_mc import TwoLevelSetup
#       7 from graph_mlmc_model import GraphTwoLevelModel
# ----> 8 from mlmc_runner import MLMCRunner
#       9 from sksparse.cholmod import cholesky as sparse_cholesky
#
# File ~\Documents\summer-project\src\mlmc_runner.py:12
#       9 import numpy as np
#      11 from linear_solver import solve_linear_system
# ---> 12 from .mlmc_correction import (
#      13     SampleCorrection,
#      14     SystemSolver,
#      15     compute_sample_correction,
#      16 )
#      17 from .mlmc_model import MultilevelModel
#      18 from .mlmc_statistics import LevelStatistics
#
# File ~\Documents\summer-project\src\mlmc_correction.py:10
#       6 from typing import TypeVar
#       8 import numpy as np
# ---> 10 from .linear_solver import (
#      11     LinearSolveResult,
#      12     LinearSystem,
#      13     solve_linear_system,
#      14 )
#      15 from .mlmc_model import MultilevelModel
#      18 RandomnessT = TypeVar("RandomnessT")
#
# ImportError: attempted relative import with no known parent package

# %%
edges, n_vertices, edge_weights = load_graph(r"../../data/raw/power-US-Grid.mtx")
num_components = check_connectivity(edges, n_vertices)
if num_components > 1:
    edges, n_vertices, edge_weights = filter_to_largest_component(edges, n_vertices, edge_weights)

A, D, L = build_graph_matrices(edges, n_vertices)
lambda_min = compute_lambda_min(L, D)
L_sigma = build_shifted_laplacian(L, D, lambda_min)

import networkx as nx
G_nx = nx.Graph()
G_nx.add_edges_from(edges)
gamma_in, gamma_out, diameter = find_diameter_endpoints(G_nx, n_sample=5, k_hop=4)
